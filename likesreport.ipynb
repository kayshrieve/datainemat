# %% [markdown]
# <h2>likes report!</h2>
# <h3>Kay Shrieve</h3>
# I got this data from my own instagram account, through instagram.

# %%
import json 
import pandas as pd

# %%
with open (r'C:\Users\kgshr_000\Documents\instadata\likes.json') as l:
    likes = json.load(l)
#likes

# %%
#likes_df = pd.DataFrame(likes)

# %%
likes.keys()
# Out:
# dict_keys(['media_likes', 'comment_likes'])

# %%
print(len(likes['media_likes']), len(likes['comment_likes']))
# Out:
# 5246 14

# %%
dlikes_df = pd.DataFrame(likes['media_likes'], columns = ['timestamp', 'account'])
dlikes_df.head()
# Out:
#                    timestamp          account
# 0  2021-02-02T09:21:47+00:00     julia.frisco
# 1  2021-02-02T09:12:41+00:00  reversecorngirl
# 2  2021-02-02T09:12:28+00:00     andrealowen_
# 3  2021-02-02T08:54:44+00:00  heir.of.atticus
# 4  2021-02-02T08:52:04+00:00        legitcrys

# %%
count_dlikes = dlikes_df.groupby('account').count()
count_dlikes[:10]
# Out:
#                 timestamp
# account
# 00jesi_                 2
# 1pageatatime            2
# 41.becker_              5
# 5683collective          1
# 81twentythree          16
# 99mlk                   3
# _.knoir_                2
# ___xozo___              1
# __h0rse___              2
# __sammers___            1

# %%
count_dlikes.sort_values('timestamp' ,ascending=False).head()
# Out:
#                  timestamp
# account
# glamourkillsco         103
# _sainte                 94
# samdesantiss            63
# ryanscottgraham         62
# brittany_noff           56

# %%
from matplotlib import pyplot as plt

# %%
sortcount = count_dlikes.sort_values('timestamp' ,ascending=False)
labels = sortcount['timestamp'].keys()
vals = sortcount['timestamp']
width = .5

fig, ax = plt.subplots(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
ax.bar(labels, vals, width)
ax.set_ylabel('Likes')
plt.xticks(rotation=90, fontsize = 'small')
plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.pie(vals, labels = labels)
ax2.axis('equal')
plt.show()

# %%
toplikes = count_dlikes['timestamp'] > 50
countstop, countsbot = sortcount[toplikes], sortcount[-toplikes]
other = countsbot.sum()

piedat = countstop.append(pd.DataFrame(other['timestamp'], columns = ['timestamp'], index = ['other < 50']))
piedat.head()
# Out:
# <ipython-input-35-c044abe194bb>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   countstop, countsbot = sortcount[toplikes], sortcount[-toplikes]
#                  timestamp
# glamourkillsco         103
# _sainte                 94
# samdesantiss            63
# ryanscottgraham         62
# brittany_noff           56

# %%
vals = piedat['timestamp']
labels = piedat['timestamp'].keys()


fig3, ax3 = plt.subplots()
ax3.pie(vals, labels = labels)
ax3.axis('equal')
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(count_dlikes)
# Out:
# E:\Anaconda\envs\datainemat\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# <h4>in conclusion</h4>
# I have a lot of likes to a clothing company that doesn't even exist anymore, and then the rest of them are just my friends. This also shows that I use instagram a little bit too much because the plots are barely readable.
